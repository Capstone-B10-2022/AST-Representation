# %%
print('hello')
# Out:
# hello

# %%
import re
import os
import glob

# %%
def remove_comments(filename1, filename2,lang):
    """ Remove all comments beginning with # from filename1 and writes
    the result to filename2
    """

    with open(filename1, 'r') as f:
        lines = f.readlines()

    with open(filename2, 'w') as f:
        if lang == '*.py':
            for line in lines:
                # Keep the Shebang line
                if line[0:2] == "#!":
                    f.writelines(line)
                # Also keep existing empty lines
                elif not line.strip():
                    f.writelines(line)
                # But remove comments from other lines
                else:
                    line = line.split('#')
                    stripped_string = line[0].rstrip()
                    # Write the line only if the comment was after the code.
                    # Discard lines that only contain comments.
                    if stripped_string:
                        f.writelines(stripped_string)
                        f.writelines('\n')
        else:
            text = ''
            for i in lines:
                text += i
            #COMMENTS = re.compile(r'''(//[^\n]*(?:\n|$))|(/\*.*?\*/)''',re.VERBOSE)
            out = re.sub('//.*?\n|/\*.*?\*/', '', text, flags=re.S)
            f.writelines(out)

# %%
for i in ['*.py','*.c','*.java']:
    Codeset = 'C:/Users/nikhi/OneDrive/Documents/gitUploads/Frontend/dataset/v1'    #Path to you folder with files
    for code_path in sorted(glob.glob(os.path.join(Codeset, i))):
        code_path = code_path.replace("/","\\")
        if i == '*.py':
            temp = 'temp.py'
        elif i == '*.c':
            temp = 'temp.c'
        else:
            temp = 'temp.java'
        filename2= temp
        remove_comments(code_path,filename2,i)
        f = open(filename2,'r')
        print(f.read())
# Out:
# import sys
# A = [64, 25, 12, 22, 11]
#
# for i in range(len(A)):
#
#     min_idx = i
#     for j in range(i+1, len(A)):
#         if A[min_idx] > A[j]:
#             min_idx = j
#
#     A[i], A[min_idx] = A[min_idx], A[i]
#
# print ("Sorted array")
# for i in range(len(A)):
#     print("%d" %A[i],end=" ")
#
#
# def bubbleSort(arr):
#     n = len(arr)
#
#     for i in range(n):
#         swapped = False
#
#         for j in range(0, n-i-1):
#
#             if arr[j] > arr[j+1] :
#                 arr[j], arr[j+1] = arr[j+1], arr[j]
#                 swapped = True
#
#         if swapped == False:
#             break
#
# arr = [64, 34, 25, 12, 22, 11, 90]
#
# bubbleSort(arr)
#
# print ("Sorted array :")
# for i in range(len(arr)):
#     print ("%d" %arr[i],end=" ")
#
#
#
#
# #include <stdio.h>
#
# int main(){
#     int N = 2;
#     int count = 0;
#     for (int i = N; i > 0; i /= 2)
#     for (int j = 0; j < i; j++)
#         count++;
# }
#
#
# #include <stdio.h>
#
# ...

# %%
filename1 = 'C:/Users/nikhi/OneDrive/Documents/gitUploads/Frontend/dataset/v1/sq1.py' 
with open(filename1, 'r') as f:
    lines = f.readlines()
f.close()
filename2 = 'C:/Users/nikhi/OneDrive/Documents/gitUploads/Frontend/dataset/v1/sq1.py' 
with open(filename2, 'w') as f:
    text = ''
    for i in lines:
        text += i
    #COMMENTS = re.compile(r'''(//[^\n]*(?:\n|$))|(/\*.*?\*/)''',re.VERBOSE)
    text = re.sub('"""[\w\W]*?"""', '', text, flags=re.S)
    out = re.sub("'''[\w\W]*?'''", '', text, flags=re.S)
    f.writelines(out)

# %%
from tqdm import tqdm
import os
import glob
from pathlib import Path
import os.path
import re

# %%
directory = r'C:\Users\nikhi\OneDrive\Documents\gitUploads\Capstone_Dataset\Python'
for root, subdirectories, files in tqdm(list(os.walk(directory))):
    for file in tqdm(list(files)):
        path = os.path.join(root, file)
        with open(path, 'r') as f:
            lines = f.readlines()
        with open(path, 'w') as f:
            text = ''
            for i in lines:
                text += i
            text = re.sub('"""[\w\W]*?"""', '', text, flags=re.S)
            out = re.sub("'''[\w\W]*?'''", '', text, flags=re.S)
            f.writelines(out)
# Out:
#   0%|                                                                                           | 0/13 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
#
# ...
#  15%|████████████▊                                                                      | 2/13 [00:03<00:18,  1.70s/it]
# 0it [00:00, ?it/s]
#
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 62.60it/s]
#
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 13/13 [00:33<00:00,  2.59s/it]
